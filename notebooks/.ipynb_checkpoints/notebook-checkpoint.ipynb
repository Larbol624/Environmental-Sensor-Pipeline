# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_timestamp
from pyspark.sql.types import (
    StructType, StructField,
    StringType, DoubleType, TimestampType, IntegerType
)


spark = SparkSession.builder \
    .appName("Clean Sensor Data") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://1062c7060189:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Clean Sensor Data</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
def test_data_minimal():
    return [{
            "sensor_id": 1,
            "timestamp": "2025-11-20T21:00:00",
            "temperature": 25.0,
            "humidity": 40.0,
            "co2": 501
            },
            {
            "sensor_id": 2,
            "timestamp": "2025-11-20T21:00:00",
            "temperature": 35.0,
            "humidity":None,
            "co2": 520
            },
            {
           "sensor_id": 3,
            "timestamp": "2025-11-20T21:00:00",
            "temperature": 18.0,
            "humidity": 20.0,
            "co2": 1900
            },
            {
           "sensor_id": 3,
            "timestamp": "2025-11-20T21:00:00",
            "temperature": 18.0,
            "humidity": 20.0,
            "co2": 1900
            },
            {
           "sensor_d": 3,
            "timestamp": "2025-11-20T21:00:00",
            "temperature": 18.0,
            "humidity": 20.0,
            "co2": 1900
            }
           ]

# %%
def clean_data(data):
    
    EXPECTED_SCHEMA = StructType([
    StructField("sensor_id", StringType(), False),
    StructField("timestamp", StringType(), False),
    StructField("temperature", DoubleType(), True),
    StructField("humidity", DoubleType(), True),
    StructField("co2", IntegerType(), True),
    ])
    
    df=spark.createDataFrame(data)
   
    schemad_df=(
        df.select(
            col("sensor_id").cast("int"),
            to_timestamp(col("timestamp").alias("timestamp")),
            col("temperature").cast("double"),
            col("humidity").cast("double"),
            col("co2").cast("int"),
            )
    )
    
    df_deduped=schemad_df.dropDuplicates()  
    df_deduped.show()

# %%
test_data=test_data_minimal()
clean_data(test_data)
# Out:
# +---------+------------------------------------+-----------+--------+----+
# |sensor_id|to_timestamp(timestamp AS timestamp)|temperature|humidity| co2|
# +---------+------------------------------------+-----------+--------+----+
# |        1|                 2025-11-20 21:00:00|       25.0|    40.0| 501|
# |        3|                 2025-11-20 21:00:00|       18.0|    20.0|1900|
# |        2|                 2025-11-20 21:00:00|       35.0|    NULL| 520|
# |     NULL|                 2025-11-20 21:00:00|       18.0|    20.0|1900|
# +---------+------------------------------------+-----------+--------+----+
